# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

from src.unconstrained_min import *
from tests.examples import *

# %%
x0 = np.array([1, 1])
obj_tol = 1e-8
param_tol = 1e-12
max_iter = 100
wolfe_const = 0.01
backtracking_const = 0.5

# %%
minimizer = MinimizerWrapper(obj_tol, param_tol, max_iter, wolfe_const, backtracking_const)

# %%
minimizer.solve(rotated_ellipses, x0)
minimizer.plot()
# Out:
# Solving using GD minimizer...
# [0] x: [1 1], y: 15.263485025340572
# [1] x: [0.49403527 1.26747277], y: 6.047207640907514
# [2] x: [0.76213207 1.08842601], y: 3.093362626465863
# [3] x: [0.5950772  1.16099326], y: 2.122161050022154
# [4] x: [0.67304906 1.09246742], y: 1.7794146463794516
# [5] x: [0.61344333 1.10373936], y: 1.6366146117835108
# [6] x: [0.63147103 1.0705512 ], y: 1.5581440001453417
# [7] x: [0.58067321 1.05503149], y: 1.5103688528534223
# [8] x: [0.60460606 1.01949067], y: 1.4239244809838787
# [9] x: [0.54858052 1.00906953], y: 1.4050254353781693
# [10] x: [0.57946128 0.97052501], y: 1.3048619162058885
# [11] x: [0.54821526 0.96817307], y: 1.2464951161810418
# [12] x: [0.55604946 0.92350358], y: 1.2008663936681265
# [13] x: [0.52083489 0.9243888 ], y: 1.1380454292112336
# [14] x: [0.53440088 0.87827232], y: 1.1124065367790443
# [15] x: [0.49434365 0.88285548], y: 1.0413573277582366
# [16] x: [0.50445484 0.85876364], y: 0.9975019412451757
# ...

# %%
minimizer.solve(rotated_ellipses, x0)
minimizer.plot()
# Out:
# Solving using GD minimizer...
# [0] x: [1 1], y: 15.263485025340572
# [1] x: [0.49403527 1.26747277], y: 6.047207640907514
# [2] x: [0.76213207 1.08842601], y: 3.093362626465863
# [3] x: [0.5950772  1.16099326], y: 2.122161050022154
# [4] x: [0.67304906 1.09246742], y: 1.7794146463794516
# [5] x: [0.61344333 1.10373936], y: 1.6366146117835108
# [6] x: [0.63147103 1.0705512 ], y: 1.5581440001453417
# [7] x: [0.58067321 1.05503149], y: 1.5103688528534223
# [8] x: [0.60460606 1.01949067], y: 1.4239244809838787
# [9] x: [0.54858052 1.00906953], y: 1.4050254353781693
# [10] x: [0.57946128 0.97052501], y: 1.3048619162058885
# [11] x: [0.54821526 0.96817307], y: 1.2464951161810418
# [12] x: [0.55604946 0.92350358], y: 1.2008663936681265
# [13] x: [0.52083489 0.9243888 ], y: 1.1380454292112336
# [14] x: [0.53440088 0.87827232], y: 1.1124065367790443
# [15] x: [0.49434365 0.88285548], y: 1.0413573277582366
# [16] x: [0.50445484 0.85876364], y: 0.9975019412451757
# ...
